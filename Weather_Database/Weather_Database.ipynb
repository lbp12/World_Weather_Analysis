# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy
# Import the requests library.
import requests
# Import the API key.
from config2 import weather_api_key
import time
from datetime import datetime

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.00, high=180.00, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 754

# %%
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1

# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | udachnyy
# Processing Record 2 of Set 1 | cape town
# Processing Record 3 of Set 1 | hilo
# Processing Record 4 of Set 1 | albany
# Processing Record 5 of Set 1 | garmsar
# Processing Record 6 of Set 1 | kapaa
# Processing Record 7 of Set 1 | dikson
# Processing Record 8 of Set 1 | pak chong
# Processing Record 9 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 10 of Set 1 | leghorn
# City not found. Skipping...
# Processing Record 11 of Set 1 | qaqortoq
# Processing Record 12 of Set 1 | ylivieska
# Processing Record 13 of Set 1 | muktsar
# Processing Record 14 of Set 1 | port alfred
# Processing Record 15 of Set 1 | arraial do cabo
# Processing Record 16 of Set 1 | meadville
# Processing Record 17 of Set 1 | grand river south east
# City not found. Skipping...
# Processing Record 18 of Set 1 | bluff
# Processing Record 19 of Set 1 | fallon
# Processing Record 20 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 21 of Set 1 | marcona
# City not found. Skipping...
# Processing Record 22 of Set 1 | santa barbara
# Processing Record 23 of Set 1 | tasiilaq
# Processing Record 24 of Set 1 | lagoa
# Processing Record 25 of Set 1 | jalu
# Processing Record 26 of Set 1 | wanning
# Processing Record 27 of Set 1 | bethel
# Processing Record 28 of Set 1 | muravlenko
# Processing Record 29 of Set 1 | nome
# Processing Record 30 of Set 1 | nizhneyansk
# City not found. Skipping...
# Processing Record 31 of Set 1 | chuy
# Processing Record 32 of Set 1 | barrow
# Processing Record 33 of Set 1 | ekhabi
# Processing Record 34 of Set 1 | vaini
# Processing Record 35 of Set 1 | kamarion
# Processing Record 36 of Set 1 | grindavik
# Processing Record 37 of Set 1 | acarau
# Processing Record 38 of Set 1 | kavieng
# Processing Record 39 of Set 1 | bonavista
# Processing Record 40 of Set 1 | sao joao da barra
# Processing Record 41 of Set 1 | waddan
# Processing Record 42 of Set 1 | mataura
# Processing Record 43 of Set 1 | tuatapere
# Processing Record 44 of Set 1 | kamenice nad lipou
# Processing Record 45 of Set 1 | port hedland
# Processing Record 46 of Set 1 | ushuaia
# Processing Record 47 of Set 1 | saint-joseph
# Processing Record 48 of Set 1 | sept-iles
# Processing Record 49 of Set 1 | bundaberg
# Processing Record 50 of Set 1 | hermanus
# Processing Record 1 of Set 2 | leningradskiy
# Processing Record 2 of Set 2 | ponta do sol
# Processing Record 3 of Set 2 | lebu
# Processing Record 4 of Set 2 | tuktoyaktuk
# Processing Record 5 of Set 2 | san patricio
# Processing Record 6 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 7 of Set 2 | cayenne
# Processing Record 8 of Set 2 | noyabrsk
# Processing Record 9 of Set 2 | constitucion
# Processing Record 10 of Set 2 | puerto barrios
# Processing Record 11 of Set 2 | scottsburgh
# City not found. Skipping...
# Processing Record 12 of Set 2 | chokurdakh
# Processing Record 13 of Set 2 | talnakh
# Processing Record 14 of Set 2 | ahipara
# Processing Record 15 of Set 2 | goderich
# Processing Record 16 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 17 of Set 2 | narsaq
# Processing Record 18 of Set 2 | gisborne
# Processing Record 19 of Set 2 | goure
# Processing Record 20 of Set 2 | luganville
# Processing Record 21 of Set 2 | havoysund
# Processing Record 22 of Set 2 | hailar
# Processing Record 23 of Set 2 | oskarshamn
# Processing Record 24 of Set 2 | te anau
# Processing Record 25 of Set 2 | galveston
# Processing Record 26 of Set 2 | butaritari
# Processing Record 27 of Set 2 | kaitangata
# Processing Record 28 of Set 2 | puerto leguizamo
# Processing Record 29 of Set 2 | bengkulu
# Processing Record 30 of Set 2 | hurghada
# Processing Record 31 of Set 2 | jamestown
# Processing Record 32 of Set 2 | yarada
# Processing Record 33 of Set 2 | borogontsy
# Processing Record 34 of Set 2 | iralaya
# Processing Record 35 of Set 2 | veraval
# Processing Record 36 of Set 2 | airai
# Processing Record 37 of Set 2 | maputo
# Processing Record 38 of Set 2 | viedma
# Processing Record 39 of Set 2 | sao filipe
# Processing Record 40 of Set 2 | san pedro
# Processing Record 41 of Set 2 | la ronge
# Processing Record 42 of Set 2 | busselton
# Processing Record 43 of Set 2 | kisangani
# Processing Record 44 of Set 2 | suluq
# Processing Record 45 of Set 2 | troitskoye
# Processing Record 46 of Set 2 | yellowknife
# Processing Record 47 of Set 2 | dongsheng
# Processing Record 48 of Set 2 | porgera
# Processing Record 49 of Set 2 | rameswaram
# Processing Record 50 of Set 2 | tobermory
# Processing Record 1 of Set 3 | slave lake
# Processing Record 2 of Set 3 | zeya
# Processing Record 3 of Set 3 | east london
# Processing Record 4 of Set 3 | cap-aux-meules
# Processing Record 5 of Set 3 | uyemskiy
# Processing Record 6 of Set 3 | mudyuga
# City not found. Skipping...
# Processing Record 7 of Set 3 | do rud
# City not found. Skipping...
# Processing Record 8 of Set 3 | atar
# Processing Record 9 of Set 3 | hobart
# Processing Record 10 of Set 3 | anloga
# Processing Record 11 of Set 3 | quatre cocos
# Processing Record 12 of Set 3 | chagda
# City not found. Skipping...
# Processing Record 13 of Set 3 | hithadhoo
# Processing Record 14 of Set 3 | louisbourg
# City not found. Skipping...
# Processing Record 15 of Set 3 | esperance
# Processing Record 16 of Set 3 | bredasdorp
# Processing Record 17 of Set 3 | bambous virieux
# Processing Record 18 of Set 3 | puerto ayora
# Processing Record 19 of Set 3 | saint-philippe
# Processing Record 20 of Set 3 | ostrovnoy
# Processing Record 21 of Set 3 | estelle
# Processing Record 22 of Set 3 | qaanaaq
# Processing Record 23 of Set 3 | sergeyevka
# Processing Record 24 of Set 3 | torbay
# Processing Record 25 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 26 of Set 3 | hobyo
# Processing Record 27 of Set 3 | bagotville
# Processing Record 28 of Set 3 | kuche
# City not found. Skipping...
# Processing Record 29 of Set 3 | faanui
# Processing Record 30 of Set 3 | provideniya
# Processing Record 31 of Set 3 | mys shmidta
# City not found. Skipping...
# Processing Record 32 of Set 3 | victoria
# Processing Record 33 of Set 3 | mount isa
# Processing Record 34 of Set 3 | marawi
# Processing Record 35 of Set 3 | punta arenas
# Processing Record 36 of Set 3 | toliary
# City not found. Skipping...
# Processing Record 37 of Set 3 | palabuhanratu
# City not found. Skipping...
# Processing Record 38 of Set 3 | waingapu
# Processing Record 39 of Set 3 | gogrial
# Processing Record 40 of Set 3 | abha
# Processing Record 41 of Set 3 | ati
# Processing Record 42 of Set 3 | polyarnyy
# Processing Record 43 of Set 3 | luderitz
# Processing Record 44 of Set 3 | longonjo
# Processing Record 45 of Set 3 | makubetsu
# Processing Record 46 of Set 3 | sulina
# Processing Record 47 of Set 3 | pangnirtung
# Processing Record 48 of Set 3 | upernavik
# Processing Record 49 of Set 3 | kilindoni
# Processing Record 50 of Set 3 | georgetown
# Processing Record 1 of Set 4 | new norfolk
# Processing Record 2 of Set 4 | avera
# Processing Record 3 of Set 4 | genhe
# Processing Record 4 of Set 4 | castro
# Processing Record 5 of Set 4 | kodiak
# Processing Record 6 of Set 4 | nikolskoye
# Processing Record 7 of Set 4 | bayshore gardens
# Processing Record 8 of Set 4 | sabha
# Processing Record 9 of Set 4 | nakamura
# Processing Record 10 of Set 4 | blumberg
# Processing Record 11 of Set 4 | palu
# Processing Record 12 of Set 4 | bandarbeyla
# Processing Record 13 of Set 4 | rikitea
# Processing Record 14 of Set 4 | pontal do parana
# Processing Record 15 of Set 4 | gurskoye
# City not found. Skipping...
# Processing Record 16 of Set 4 | puerto maldonado
# Processing Record 17 of Set 4 | port macquarie
# Processing Record 18 of Set 4 | ribeira grande
# Processing Record 19 of Set 4 | severomuysk
# Processing Record 20 of Set 4 | bonthe
# Processing Record 21 of Set 4 | atuona
# Processing Record 22 of Set 4 | changping
# Processing Record 23 of Set 4 | bargal
# City not found. Skipping...
# Processing Record 24 of Set 4 | trincomalee
# Processing Record 25 of Set 4 | raga
# Processing Record 26 of Set 4 | kihei
# Processing Record 27 of Set 4 | morondava
# Processing Record 28 of Set 4 | zhezkazgan
# Processing Record 29 of Set 4 | cobadin
# Processing Record 30 of Set 4 | komsomolskiy
# Processing Record 31 of Set 4 | ondorhaan
# City not found. Skipping...
# Processing Record 32 of Set 4 | kazalinsk
# City not found. Skipping...
# Processing Record 33 of Set 4 | umm kaddadah
# Processing Record 34 of Set 4 | aripuana
# Processing Record 35 of Set 4 | geraldton
# Processing Record 36 of Set 4 | basoko
# Processing Record 37 of Set 4 | monrovia
# Processing Record 38 of Set 4 | salinas
# Processing Record 39 of Set 4 | kempele
# Processing Record 40 of Set 4 | jining
# Processing Record 41 of Set 4 | vao
# Processing Record 42 of Set 4 | sola
# Processing Record 43 of Set 4 | barroualie
# City not found. Skipping...
# Processing Record 44 of Set 4 | kostino
# Processing Record 45 of Set 4 | ahuimanu
# Processing Record 46 of Set 4 | cidreira
# Processing Record 47 of Set 4 | volksrust
# Processing Record 48 of Set 4 | iqaluit
# Processing Record 49 of Set 4 | andros town
# Processing Record 50 of Set 4 | nuuk
# Processing Record 1 of Set 5 | fortuna
# Processing Record 2 of Set 5 | aykhal
# Processing Record 3 of Set 5 | cabo san lucas
# Processing Record 4 of Set 5 | mahajanga
# Processing Record 5 of Set 5 | odienne
# Processing Record 6 of Set 5 | carnarvon
# Processing Record 7 of Set 5 | sorland
# Processing Record 8 of Set 5 | kavaratti
# Processing Record 9 of Set 5 | sao miguel do araguaia
# Processing Record 10 of Set 5 | tumannyy
# City not found. Skipping...
# Processing Record 11 of Set 5 | watsa
# Processing Record 12 of Set 5 | atoka
# Processing Record 13 of Set 5 | dolneni
# Processing Record 14 of Set 5 | sharan
# Processing Record 15 of Set 5 | thompson
# Processing Record 16 of Set 5 | hasaki
# Processing Record 17 of Set 5 | bulgan
# Processing Record 18 of Set 5 | phalaborwa
# Processing Record 19 of Set 5 | san policarpo
# Processing Record 20 of Set 5 | grand centre
# City not found. Skipping...
# Processing Record 21 of Set 5 | nichinan
# Processing Record 22 of Set 5 | haines junction
# Processing Record 23 of Set 5 | yinchuan
# Processing Record 24 of Set 5 | okha
# Processing Record 25 of Set 5 | qiongshan
# Processing Record 26 of Set 5 | vaitupu
# City not found. Skipping...
# Processing Record 27 of Set 5 | rongcheng
# Processing Record 28 of Set 5 | north platte
# Processing Record 29 of Set 5 | rio grande
# Processing Record 30 of Set 5 | pisco
# Processing Record 31 of Set 5 | fomboni
# Processing Record 32 of Set 5 | swan river
# Processing Record 33 of Set 5 | guerrero negro
# Processing Record 34 of Set 5 | lompoc
# Processing Record 35 of Set 5 | asheboro
# Processing Record 36 of Set 5 | trairi
# Processing Record 37 of Set 5 | pacific grove
# Processing Record 38 of Set 5 | porto novo
# Processing Record 39 of Set 5 | guangshui
# Processing Record 40 of Set 5 | lekoni
# Processing Record 41 of Set 5 | north bend
# Processing Record 42 of Set 5 | luanda
# Processing Record 43 of Set 5 | banska bystrica
# Processing Record 44 of Set 5 | poum
# Processing Record 45 of Set 5 | ijaki
# City not found. Skipping...
# Processing Record 46 of Set 5 | kupino
# Processing Record 47 of Set 5 | saleaula
# City not found. Skipping...
# Processing Record 48 of Set 5 | amderma
# City not found. Skipping...
# Processing Record 49 of Set 5 | dingle
# Processing Record 50 of Set 5 | renqiu
# Processing Record 1 of Set 6 | richards bay
# Processing Record 2 of Set 6 | samalaeulu
# City not found. Skipping...
# Processing Record 3 of Set 6 | pangkalanbuun
# Processing Record 4 of Set 6 | pindiga
# Processing Record 5 of Set 6 | ilulissat
# Processing Record 6 of Set 6 | vostok
# Processing Record 7 of Set 6 | saint-francois
# Processing Record 8 of Set 6 | imeni poliny osipenko
# Processing Record 9 of Set 6 | namibe
# Processing Record 10 of Set 6 | shingu
# Processing Record 11 of Set 6 | lowestoft
# Processing Record 12 of Set 6 | emerald
# Processing Record 13 of Set 6 | lorengau
# Processing Record 14 of Set 6 | ust-tarka
# Processing Record 15 of Set 6 | nouadhibou
# Processing Record 16 of Set 6 | ixtapa
# Processing Record 17 of Set 6 | saint george
# Processing Record 18 of Set 6 | gonbad-e qabus
# Processing Record 19 of Set 6 | gorele
# Processing Record 20 of Set 6 | kollumerland
# City not found. Skipping...
# Processing Record 21 of Set 6 | nan
# Processing Record 22 of Set 6 | saldanha
# Processing Record 23 of Set 6 | meulaboh
# Processing Record 24 of Set 6 | mullaitivu
# City not found. Skipping...
# Processing Record 25 of Set 6 | moerai
# Processing Record 26 of Set 6 | klaksvik
# Processing Record 27 of Set 6 | bagalkot
# Processing Record 28 of Set 6 | kieta
# Processing Record 29 of Set 6 | verkhniye sergi
# Processing Record 30 of Set 6 | west memphis
# Processing Record 31 of Set 6 | khatanga
# Processing Record 32 of Set 6 | krasnogvardeyets
# Processing Record 33 of Set 6 | port lincoln
# Processing Record 34 of Set 6 | oktyabrskiy
# Processing Record 35 of Set 6 | yenagoa
# Processing Record 36 of Set 6 | anadyr
# Processing Record 37 of Set 6 | cockburn town
# Processing Record 38 of Set 6 | dien bien
# City not found. Skipping...
# Processing Record 39 of Set 6 | sentyabrskiy
# City not found. Skipping...
# Processing Record 40 of Set 6 | taseyevo
# Processing Record 41 of Set 6 | opuwo
# Processing Record 42 of Set 6 | freetown
# Processing Record 43 of Set 6 | port elizabeth
# Processing Record 44 of Set 6 | manaure
# Processing Record 45 of Set 6 | yara
# Processing Record 46 of Set 6 | angoche
# Processing Record 47 of Set 6 | antofagasta
# Processing Record 48 of Set 6 | buraydah
# Processing Record 49 of Set 6 | araouane
# Processing Record 50 of Set 6 | gouyave
# Processing Record 1 of Set 7 | cabedelo
# Processing Record 2 of Set 7 | benjamin constant
# Processing Record 3 of Set 7 | honiara
# Processing Record 4 of Set 7 | saskylakh
# Processing Record 5 of Set 7 | severo-kurilsk
# Processing Record 6 of Set 7 | mackenzie
# Processing Record 7 of Set 7 | codrington
# Processing Record 8 of Set 7 | inuvik
# Processing Record 9 of Set 7 | norman wells
# Processing Record 10 of Set 7 | bizhbulyak
# Processing Record 11 of Set 7 | tromso
# Processing Record 12 of Set 7 | santo antonio do ica
# Processing Record 13 of Set 7 | abu samrah
# Processing Record 14 of Set 7 | johnstown
# Processing Record 15 of Set 7 | oistins
# Processing Record 16 of Set 7 | gigmoto
# Processing Record 17 of Set 7 | waipawa
# Processing Record 18 of Set 7 | emba
# Processing Record 19 of Set 7 | sitka
# Processing Record 20 of Set 7 | iquique
# Processing Record 21 of Set 7 | shevchenkove
# Processing Record 22 of Set 7 | artyk
# City not found. Skipping...
# Processing Record 23 of Set 7 | campbell river
# Processing Record 24 of Set 7 | berlevag
# Processing Record 25 of Set 7 | beberibe
# Processing Record 26 of Set 7 | havre-saint-pierre
# Processing Record 27 of Set 7 | grand gaube
# Processing Record 28 of Set 7 | longyearbyen
# Processing Record 29 of Set 7 | christchurch
# Processing Record 30 of Set 7 | huainan
# Processing Record 31 of Set 7 | naumburg
# Processing Record 32 of Set 7 | zhangye
# Processing Record 33 of Set 7 | college
# Processing Record 34 of Set 7 | lavrentiya
# Processing Record 35 of Set 7 | kruisfontein
# Processing Record 36 of Set 7 | yuzhno-kurilsk
# Processing Record 37 of Set 7 | todos santos
# Processing Record 38 of Set 7 | salalah
# Processing Record 39 of Set 7 | kaeo
# Processing Record 40 of Set 7 | hvide sande
# Processing Record 41 of Set 7 | san marcos
# Processing Record 42 of Set 7 | attawapiskat
# City not found. Skipping...
# Processing Record 43 of Set 7 | margate
# Processing Record 44 of Set 7 | kununurra
# Processing Record 45 of Set 7 | saint anthony
# Processing Record 46 of Set 7 | nelson bay
# Processing Record 47 of Set 7 | utiroa
# City not found. Skipping...
# Processing Record 48 of Set 7 | izhma
# Processing Record 49 of Set 7 | katsuura
# Processing Record 50 of Set 7 | bac lieu
# Processing Record 1 of Set 8 | lanxi
# Processing Record 2 of Set 8 | kandrian
# Processing Record 3 of Set 8 | ilheus
# Processing Record 4 of Set 8 | mulege
# Processing Record 5 of Set 8 | vaxjo
# Processing Record 6 of Set 8 | suphan buri
# Processing Record 7 of Set 8 | kuching
# Processing Record 8 of Set 8 | tawnat
# City not found. Skipping...
# Processing Record 9 of Set 8 | clyde river
# Processing Record 10 of Set 8 | severo-yeniseyskiy
# Processing Record 11 of Set 8 | hohhot
# Processing Record 12 of Set 8 | kokopo
# Processing Record 13 of Set 8 | ust-koksa
# Processing Record 14 of Set 8 | nanortalik
# Processing Record 15 of Set 8 | pedasi
# Processing Record 16 of Set 8 | hofn
# Processing Record 17 of Set 8 | flin flon
# Processing Record 18 of Set 8 | royan
# Processing Record 19 of Set 8 | partur
# Processing Record 20 of Set 8 | ponerihouen
# Processing Record 21 of Set 8 | mokhsogollokh
# Processing Record 22 of Set 8 | obera
# Processing Record 23 of Set 8 | utete
# Processing Record 24 of Set 8 | moron
# Processing Record 25 of Set 8 | mahebourg
# Processing Record 26 of Set 8 | mar del plata
# Processing Record 27 of Set 8 | mecca
# Processing Record 28 of Set 8 | labuhan
# Processing Record 29 of Set 8 | tikrit
# Processing Record 30 of Set 8 | melton
# Processing Record 31 of Set 8 | deming
# Processing Record 32 of Set 8 | khao yoi
# Processing Record 33 of Set 8 | bud
# Processing Record 34 of Set 8 | kudahuvadhoo
# Processing Record 35 of Set 8 | iwanai
# Processing Record 36 of Set 8 | weyburn
# Processing Record 37 of Set 8 | hovd
# Processing Record 38 of Set 8 | comodoro rivadavia
# Processing Record 39 of Set 8 | yuncheng
# Processing Record 40 of Set 8 | tegh
# Processing Record 41 of Set 8 | moyale
# Processing Record 42 of Set 8 | vila franca do campo
# Processing Record 43 of Set 8 | japura
# Processing Record 44 of Set 8 | vardo
# Processing Record 45 of Set 8 | seoul
# Processing Record 46 of Set 8 | sao gabriel da cachoeira
# Processing Record 47 of Set 8 | mountain home
# Processing Record 48 of Set 8 | balsas
# Processing Record 49 of Set 8 | linhares
# Processing Record 50 of Set 8 | mogzon
# Processing Record 1 of Set 9 | kloulklubed
# Processing Record 2 of Set 9 | ishinomaki
# Processing Record 3 of Set 9 | xian
# Processing Record 4 of Set 9 | turukhansk
# Processing Record 5 of Set 9 | englehart
# Processing Record 6 of Set 9 | khash
# Processing Record 7 of Set 9 | fairbanks
# Processing Record 8 of Set 9 | port blair
# Processing Record 9 of Set 9 | barcelos
# Processing Record 10 of Set 9 | ponta delgada
# Processing Record 11 of Set 9 | kyra
# Processing Record 12 of Set 9 | igrim
# Processing Record 13 of Set 9 | talisay
# Processing Record 14 of Set 9 | faya
# Processing Record 15 of Set 9 | coquimbo
# Processing Record 16 of Set 9 | mehamn
# Processing Record 17 of Set 9 | zhanaozen
# Processing Record 18 of Set 9 | kupang
# Processing Record 19 of Set 9 | srednekolymsk
# Processing Record 20 of Set 9 | inirida
# Processing Record 21 of Set 9 | suez
# Processing Record 22 of Set 9 | harper
# Processing Record 23 of Set 9 | cherskiy
# Processing Record 24 of Set 9 | belaya gora
# Processing Record 25 of Set 9 | lubartow
# Processing Record 26 of Set 9 | lishui
# Processing Record 27 of Set 9 | gushikawa
# Processing Record 28 of Set 9 | isangel
# Processing Record 29 of Set 9 | kaiyuan
# Processing Record 30 of Set 9 | chumikan
# Processing Record 31 of Set 9 | khani
# Processing Record 32 of Set 9 | dianopolis
# City not found. Skipping...
# Processing Record 33 of Set 9 | raduzhnyy
# Processing Record 34 of Set 9 | trinec
# Processing Record 35 of Set 9 | carauari
# Processing Record 36 of Set 9 | malanje
# Processing Record 37 of Set 9 | henderson
# Processing Record 38 of Set 9 | rong kwang
# Processing Record 39 of Set 9 | shaoxing
# Processing Record 40 of Set 9 | doha
# Processing Record 41 of Set 9 | kalmunai
# Processing Record 42 of Set 9 | vilcun
# Processing Record 43 of Set 9 | ozernovskiy
# Processing Record 44 of Set 9 | yiyang
# Processing Record 45 of Set 9 | tomatlan
# Processing Record 46 of Set 9 | wamba
# Processing Record 47 of Set 9 | floro
# Processing Record 48 of Set 9 | buka
# Processing Record 49 of Set 9 | aguimes
# Processing Record 50 of Set 9 | rawson
# Processing Record 1 of Set 10 | sofiysk
# City not found. Skipping...
# Processing Record 2 of Set 10 | eatonton
# Processing Record 3 of Set 10 | iringa
# Processing Record 4 of Set 10 | ilhabela
# Processing Record 5 of Set 10 | billings
# Processing Record 6 of Set 10 | karabuk
# Processing Record 7 of Set 10 | vila velha
# Processing Record 8 of Set 10 | toamua
# City not found. Skipping...
# Processing Record 9 of Set 10 | ler
# Processing Record 10 of Set 10 | kiunga
# Processing Record 11 of Set 10 | hanko
# Processing Record 12 of Set 10 | maragogi
# Processing Record 13 of Set 10 | katobu
# Processing Record 14 of Set 10 | harindanga
# Processing Record 15 of Set 10 | soroti
# Processing Record 16 of Set 10 | buala
# Processing Record 17 of Set 10 | hihifo
# City not found. Skipping...
# Processing Record 18 of Set 10 | praia da vitoria
# Processing Record 19 of Set 10 | el alto
# Processing Record 20 of Set 10 | loudi
# Processing Record 21 of Set 10 | caravelas
# Processing Record 22 of Set 10 | padang
# Processing Record 23 of Set 10 | talara
# Processing Record 24 of Set 10 | mount gambier
# Processing Record 25 of Set 10 | san cristobal
# Processing Record 26 of Set 10 | jacqueville
# Processing Record 27 of Set 10 | camana
# Processing Record 28 of Set 10 | chippewa falls
# Processing Record 29 of Set 10 | hamilton
# Processing Record 30 of Set 10 | tevaitoa
# Processing Record 31 of Set 10 | zavyalovo
# Processing Record 32 of Set 10 | alofi
# Processing Record 33 of Set 10 | dunedin
# Processing Record 34 of Set 10 | yamada
# Processing Record 35 of Set 10 | kotido
# Processing Record 36 of Set 10 | karauzyak
# City not found. Skipping...
# Processing Record 37 of Set 10 | grants pass
# Processing Record 38 of Set 10 | tevriz
# Processing Record 39 of Set 10 | hervey bay
# Processing Record 40 of Set 10 | belmonte
# Processing Record 41 of Set 10 | tutoia
# Processing Record 42 of Set 10 | nizhniy ufaley
# Processing Record 43 of Set 10 | casas grandes
# Processing Record 44 of Set 10 | skjervoy
# Processing Record 45 of Set 10 | hami
# Processing Record 46 of Set 10 | decatur
# Processing Record 47 of Set 10 | bernay
# Processing Record 48 of Set 10 | mindyak
# Processing Record 49 of Set 10 | antibes
# Processing Record 50 of Set 10 | los llanos de aridane
# Processing Record 1 of Set 11 | zheleznodorozhnyy
# Processing Record 2 of Set 11 | kailua
# Processing Record 3 of Set 11 | aklavik
# Processing Record 4 of Set 11 | lesnoy
# Processing Record 5 of Set 11 | la jagua del pilar
# Processing Record 6 of Set 11 | mahibadhoo
# Processing Record 7 of Set 11 | vanderhoof
# Processing Record 8 of Set 11 | marv dasht
# City not found. Skipping...
# Processing Record 9 of Set 11 | namatanai
# Processing Record 10 of Set 11 | santa maria
# Processing Record 11 of Set 11 | boden
# Processing Record 12 of Set 11 | laguna
# Processing Record 13 of Set 11 | souillac
# Processing Record 14 of Set 11 | mujiayingzi
# Processing Record 15 of Set 11 | paamiut
# Processing Record 16 of Set 11 | okegawa
# Processing Record 17 of Set 11 | le port
# Processing Record 18 of Set 11 | lugovoy
# Processing Record 19 of Set 11 | kalengwa
# Processing Record 20 of Set 11 | ballina
# Processing Record 21 of Set 11 | tanout
# Processing Record 22 of Set 11 | kyakhta
# Processing Record 23 of Set 11 | koumac
# Processing Record 24 of Set 11 | mingguang
# Processing Record 25 of Set 11 | samusu
# City not found. Skipping...
# Processing Record 26 of Set 11 | vigrestad
# Processing Record 27 of Set 11 | vanavara
# Processing Record 28 of Set 11 | sinnamary
# Processing Record 29 of Set 11 | galgani
# City not found. Skipping...
# Processing Record 30 of Set 11 | horsham
# Processing Record 31 of Set 11 | tifton
# Processing Record 32 of Set 11 | riviere-au-renard
# Processing Record 33 of Set 11 | sundby
# Processing Record 34 of Set 11 | gizo
# Processing Record 35 of Set 11 | guna
# Processing Record 36 of Set 11 | bolshegrivskoye
# City not found. Skipping...
# Processing Record 37 of Set 11 | paihia
# Processing Record 38 of Set 11 | paredon
# Processing Record 39 of Set 11 | sokolo
# Processing Record 40 of Set 11 | luang prabang
# Processing Record 41 of Set 11 | xiaoweizhai
# Processing Record 42 of Set 11 | chara
# Processing Record 43 of Set 11 | sabang
# Processing Record 44 of Set 11 | tazovskiy
# Processing Record 45 of Set 11 | prescott
# Processing Record 46 of Set 11 | dapaong
# Processing Record 47 of Set 11 | lata
# Processing Record 48 of Set 11 | ixhuatan
# Processing Record 49 of Set 11 | eirunepe
# Processing Record 50 of Set 11 | choix
# Processing Record 1 of Set 12 | ikire
# Processing Record 2 of Set 12 | roald
# Processing Record 3 of Set 12 | kovdor
# Processing Record 4 of Set 12 | thunder bay
# Processing Record 5 of Set 12 | khorramshahr
# Processing Record 6 of Set 12 | manokwari
# Processing Record 7 of Set 12 | jumla
# Processing Record 8 of Set 12 | touros
# Processing Record 9 of Set 12 | oranjemund
# Processing Record 10 of Set 12 | bourail
# Processing Record 11 of Set 12 | kapoeta
# Processing Record 12 of Set 12 | trinidad
# Processing Record 13 of Set 12 | bolshiye saly
# City not found. Skipping...
# Processing Record 14 of Set 12 | castelo do piaui
# Processing Record 15 of Set 12 | edd
# Processing Record 16 of Set 12 | luau
# Processing Record 17 of Set 12 | ust-nera
# Processing Record 18 of Set 12 | erenhot
# Processing Record 19 of Set 12 | pevek
# Processing Record 20 of Set 12 | fort-shevchenko
# Processing Record 21 of Set 12 | tiksi
# Processing Record 22 of Set 12 | revere
# Processing Record 23 of Set 12 | pochutla
# Processing Record 24 of Set 12 | nioro
# Processing Record 25 of Set 12 | denpasar
# Processing Record 26 of Set 12 | avarua
# Processing Record 27 of Set 12 | ambodifototra
# City not found. Skipping...
# Processing Record 28 of Set 12 | bongandanga
# Processing Record 29 of Set 12 | jablah
# Processing Record 30 of Set 12 | suicheng
# Processing Record 31 of Set 12 | aldan
# Processing Record 32 of Set 12 | tateyama
# Processing Record 33 of Set 12 | hualmay
# Processing Record 34 of Set 12 | camacha
# Processing Record 35 of Set 12 | mattru
# Processing Record 36 of Set 12 | kasempa
# Processing Record 37 of Set 12 | wainwright
# Processing Record 38 of Set 12 | murray bridge
# Processing Record 39 of Set 12 | albacete
# Processing Record 40 of Set 12 | zhaozhou
# Processing Record 41 of Set 12 | deep river
# Processing Record 42 of Set 12 | kyshtovka
# Processing Record 43 of Set 12 | belgrade
# Processing Record 44 of Set 12 | itarema
# Processing Record 45 of Set 12 | itoman
# Processing Record 46 of Set 12 | wajima
# Processing Record 47 of Set 12 | loveland
# Processing Record 48 of Set 12 | otradnoye
# Processing Record 49 of Set 12 | krylovskaya
# Processing Record 50 of Set 12 | muhos
# Processing Record 1 of Set 13 | balkanabat
# Processing Record 2 of Set 13 | amapa
# Processing Record 3 of Set 13 | trebinje
# Processing Record 4 of Set 13 | tomobe
# Processing Record 5 of Set 13 | mrirt
# City not found. Skipping...
# Processing Record 6 of Set 13 | khormuj
# City not found. Skipping...
# Processing Record 7 of Set 13 | bay roberts
# Processing Record 8 of Set 13 | inta
# Processing Record 9 of Set 13 | port hawkesbury
# Processing Record 10 of Set 13 | korla
# Processing Record 11 of Set 13 | saint quentin
# City not found. Skipping...
# Processing Record 12 of Set 13 | sahrak
# City not found. Skipping...
# Processing Record 13 of Set 13 | mayor pablo lagerenza
# Processing Record 14 of Set 13 | rupert
# Processing Record 15 of Set 13 | palana
# Processing Record 16 of Set 13 | maceio
# Processing Record 17 of Set 13 | umm durman
# City not found. Skipping...
# Processing Record 18 of Set 13 | muskogee
# Processing Record 19 of Set 13 | pryazha
# Processing Record 20 of Set 13 | santana
# Processing Record 21 of Set 13 | pesqueira
# Processing Record 22 of Set 13 | tabiauea
# City not found. Skipping...
# Processing Record 23 of Set 13 | bahia honda
# Processing Record 24 of Set 13 | jizan
# Processing Record 25 of Set 13 | bucak
# Processing Record 26 of Set 13 | pokhara
# Processing Record 27 of Set 13 | kolo
# Processing Record 28 of Set 13 | kahului
# Processing Record 29 of Set 13 | galesong
# Processing Record 30 of Set 13 | silifke
# Processing Record 31 of Set 13 | beyneu
# Processing Record 32 of Set 13 | giulianova
# Processing Record 33 of Set 13 | esil
# Processing Record 34 of Set 13 | kaoma
# Processing Record 35 of Set 13 | sisimiut
# Processing Record 36 of Set 13 | were ilu
# Processing Record 37 of Set 13 | takoradi
# Processing Record 38 of Set 13 | ust-uda
# Processing Record 39 of Set 13 | ancud
# Processing Record 40 of Set 13 | sakakah
# Processing Record 41 of Set 13 | kangaatsiaq
# Processing Record 42 of Set 13 | churapcha
# Processing Record 43 of Set 13 | marica
# Processing Record 44 of Set 13 | skovorodino
# Processing Record 45 of Set 13 | neiafu
# Processing Record 46 of Set 13 | husavik
# Processing Record 47 of Set 13 | rafraf
# Processing Record 48 of Set 13 | taoudenni
# Processing Record 49 of Set 13 | beringovskiy
# Processing Record 50 of Set 13 | urumqi
# Processing Record 1 of Set 14 | gohana
# Processing Record 2 of Set 14 | raymond terrace
# Processing Record 3 of Set 14 | svetlogorsk
# Processing Record 4 of Set 14 | batagay
# Processing Record 5 of Set 14 | gawler
# Processing Record 6 of Set 14 | asau
# Processing Record 7 of Set 14 | cullera
# Processing Record 8 of Set 14 | sur
# Processing Record 9 of Set 14 | ginda
# Processing Record 10 of Set 14 | coihaique
# Processing Record 11 of Set 14 | aksu
# Processing Record 12 of Set 14 | palamos
# Processing Record 13 of Set 14 | port hardy
# Processing Record 14 of Set 14 | el tigre
# Processing Record 15 of Set 14 | tiarei
# Processing Record 16 of Set 14 | ibbenburen
# Processing Record 17 of Set 14 | cairns
# Processing Record 18 of Set 14 | barao de melgaco
# Processing Record 19 of Set 14 | filadelfia
# Processing Record 20 of Set 14 | bayir
# Processing Record 21 of Set 14 | jyvaskyla
# Processing Record 22 of Set 14 | naron
# Processing Record 23 of Set 14 | basco
# Processing Record 24 of Set 14 | badin
# Processing Record 25 of Set 14 | muli
# Processing Record 26 of Set 14 | lebedinyy
# Processing Record 27 of Set 14 | karaul
# City not found. Skipping...
# Processing Record 28 of Set 14 | nguiu
# City not found. Skipping...
# Processing Record 29 of Set 14 | makakilo city
# Processing Record 30 of Set 14 | karratha
# Processing Record 31 of Set 14 | arkadelphia
# Processing Record 32 of Set 14 | pandan
# Processing Record 33 of Set 14 | beinamar
# Processing Record 34 of Set 14 | kirishi
# Processing Record 35 of Set 14 | yeletskiy
# City not found. Skipping...
# Processing Record 36 of Set 14 | martapura
# Processing Record 37 of Set 14 | zyryanka
# Processing Record 38 of Set 14 | novotroitsk
# Processing Record 39 of Set 14 | sarangani
# Processing Record 40 of Set 14 | mana
# Processing Record 41 of Set 14 | khandbari
# Processing Record 42 of Set 14 | aljezur
# Processing Record 43 of Set 14 | belz
# Processing Record 44 of Set 14 | prince rupert
# Processing Record 45 of Set 14 | hermagor
# Processing Record 46 of Set 14 | port keats
# Processing Record 47 of Set 14 | zhigansk
# Processing Record 48 of Set 14 | pahrump
# Processing Record 49 of Set 14 | clearwater
# Processing Record 50 of Set 14 | westport
# Processing Record 1 of Set 15 | mabaruma
# Processing Record 2 of Set 15 | sambava
# Processing Record 3 of Set 15 | el dorado
# Processing Record 4 of Set 15 | half moon bay
# Processing Record 5 of Set 15 | jujuy
# City not found. Skipping...
# Processing Record 6 of Set 15 | ranfurly
# Processing Record 7 of Set 15 | dauphin
# Processing Record 8 of Set 15 | horki
# Processing Record 9 of Set 15 | paka
# Processing Record 10 of Set 15 | shepsi
# Processing Record 11 of Set 15 | lazaro cardenas
# Processing Record 12 of Set 15 | mytishchi
# Processing Record 13 of Set 15 | vilyuysk
# Processing Record 14 of Set 15 | yomitan
# City not found. Skipping...
# Processing Record 15 of Set 15 | coolidge
# Processing Record 16 of Set 15 | jacareacanga
# Processing Record 17 of Set 15 | brewster
# Processing Record 18 of Set 15 | alice springs
# Processing Record 19 of Set 15 | qorveh
# Processing Record 20 of Set 15 | chiang mai
# Processing Record 21 of Set 15 | chanute
# Processing Record 22 of Set 15 | izumo
# Processing Record 23 of Set 15 | kedougou
# Processing Record 24 of Set 15 | necochea
# Processing Record 25 of Set 15 | saint-ambroise
# Processing Record 26 of Set 15 | santo domingo
# Processing Record 27 of Set 15 | elizabeth city
# Processing Record 28 of Set 15 | itaporanga
# Processing Record 29 of Set 15 | gandai
# Processing Record 30 of Set 15 | ketchikan
# Processing Record 31 of Set 15 | trat
# Processing Record 32 of Set 15 | weymouth
# Processing Record 33 of Set 15 | flinders
# Processing Record 34 of Set 15 | halalo
# City not found. Skipping...
# Processing Record 35 of Set 15 | ocampo
# Processing Record 36 of Set 15 | conceicao da barra
# Processing Record 37 of Set 15 | kapuskasing
# Processing Record 38 of Set 15 | varsag
# Processing Record 39 of Set 15 | arenapolis
# Processing Record 40 of Set 15 | edmonton
# Processing Record 41 of Set 15 | kimbe
# Processing Record 42 of Set 15 | masallatah
# Processing Record 43 of Set 15 | juneau
# Processing Record 44 of Set 15 | adrar
# Processing Record 45 of Set 15 | ellensburg
# Processing Record 46 of Set 15 | samorin
# Processing Record 47 of Set 15 | hay river
# Processing Record 48 of Set 15 | seddon
# Processing Record 49 of Set 15 | general pico
# Processing Record 50 of Set 15 | chimore
# Processing Record 1 of Set 16 | springfield
# Processing Record 2 of Set 16 | domoni
# Processing Record 3 of Set 16 | pangai
# Processing Record 4 of Set 16 | kaka
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 693

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#         City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0   Udachnyy      RU  66.4167  112.4000     34.45        46         100
# 1  Cape Town      ZA -33.9258   18.4232     62.91        88          75
# 2       Hilo      US  19.7297 -155.0900     84.27        75          75
# 3     Albany      US  42.6001  -73.9662     50.58        24          15
# 4    Garmsar      IR  35.2182   52.3409     75.56        22          97
# 5      Kapaa      US  22.0752 -159.3190     80.58        84          75
# 6     Dikson      RU  73.5069   80.5464      6.87        91          73
# 7  Pak Chong      TH  14.7080  101.4161     75.81        81          96
# 8   Qaqortoq      GL  60.7167  -46.0333     37.44        89         100
# 9  Ylivieska      FI  64.0833   24.5500     28.31        87          22
#
#    Wind Speed Current Description
# 0        6.31     overcast clouds
# 1       13.80       broken clouds
# 2        8.05       broken clouds
# 3       11.01          few clouds
# 4        4.90     overcast clouds
# 5       13.80          light rain
# 6       19.08       broken clouds
# 7        3.51          light rain
# 8        1.45     overcast clouds
# 9        3.58          few clouds

# %%
output_data_file = 'WeatherPy_Database.csv'
city_data_df.to_csv(output_data_file, index_label='City_ID')
